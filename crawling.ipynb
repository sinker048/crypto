# %%
from crawling import get_all_binance

# %%
data = get_all_binance('ETHUSDT', '1d')
# Out:
# ...
# All caught up....!

# %%
data
# Out:
#                open     high      low    close        volume     close_time  \
# timestamp
# 2017-08-17   301.13   312.18   298.00   302.00    7030.71034  1503014399999
# 2017-08-18   302.00   311.79   283.94   293.96    9537.84646  1503100799999
# 2017-08-19   293.31   299.90   278.00   290.91    2146.19773  1503187199999
# 2017-08-20   289.41   300.53   282.85   299.10    2510.13871  1503273599999
# 2017-08-21   299.10   346.52   294.60   323.29    5219.44542  1503359999999
# ...             ...      ...      ...      ...           ...            ...
# 2022-05-28  1727.26  1808.98  1722.26  1792.22  558271.18180  1653782399999
# 2022-05-29  1792.21  1827.40  1759.96  1813.64  432430.61100  1653868799999
# 2022-05-30  1813.64  2013.00  1803.18  1998.78  814922.83590  1653955199999
# 2022-05-31  1998.78  2016.45  1925.00  1941.90  751103.42260  1654041599999
# 2022-06-01  1941.90  1958.55  1913.76  1935.54  267061.21750  1654127999999
#
# ...

# %%
import mplfinance as mpf

# %%
data = data.loc['2022-01-01':,:]

# %%
mpf.plot(data,
         type='candle',
         style='yahoo',
         volume=True,title = 'ETHUSDT',mav=(7,12))
